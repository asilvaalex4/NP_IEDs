# %%
import pickle 
import numpy as np 
from ecog_utils import erp_util
import matplotlib.pyplot as plt
from scipy.stats import zscore
import pandas as pd

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 8})#, 'font.sans-serif': 'Arial'})
plt.rcParams.update({'font.sans-serif':'Arial'})
import matplotlib as mpl
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.right'] = False
plt.rcParams['svg.fonttype'] = 'none'
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
source_path = './source_data/ED_3/'

# %%
d = np.load(f'{source_path}/spk_times.npz',allow_pickle=True)
ex_spks = d['ex_spks']
ex_ied_times = d['ex_ied_times']

# %%
from ecog_utils import np_tools
import os
import seaborn as sns
for i,spks,ts in zip(range(len(ex_ied_times)),ex_spks,ex_ied_times):
    fig,ax = plt.subplots(figsize=(2,3))
    #[-1,.4]
    np.savetxt(f'./statistical_source/ED3/neuron_spks_raster_{i}.txt', spks)
    np.savetxt(f'./statistical_source/ED3/ied_times_raster_{i}.txt', ts)

    ax = np_tools.plot_raster_to_ax(ax,spks,
                                    ts,psth=None,offset=1,t_ar=[-0.3,0.3],add_psth=False,
                                    psth_fs=100,only_spk_trs=True,
                                    spk_col='k')#pal[int(row.k_mean_cluster-1)])   
        
    ax.set(xlabel='Time relative to IED (s)',ylabel='IEDs')
